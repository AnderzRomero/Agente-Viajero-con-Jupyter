# %%
import csv
import networkx as nx
import matplotlib.pyplot as plt
import folium
import haversine

# %%
ciudades = []

with open('ciudades.csv', newline='') as csvfile:
      lectura = csv.reader(csvfile, delimiter=',')  
      next(lectura)
      for row in lectura:
        ciudad = row[0]
        latitud = float(row[1])
        longitud = float(row[2])
        ciudades.append((ciudad, latitud, longitud))
      print("Orden de la base de datos CSV")
      print(ciudades)
# Out:
# Orden de la base de datos CSV
# [('Bogota', 4.6126, -74.0705), ('Medellin', 6.2447, -75.5748), ('Cali', 3.44, -76.5197), ('Barranquilla', 10.9639, -74.7964), ('Cartagena', 10.4236, -75.5253), ('Soledad', 10.917119, -74.799151), ('Pereira', 4.8143, -75.6946), ('Bucaramanga', 7.1186, -73.1161), ('Valledupar', 10.4603, -73.2597), ('Villavicencio', 4.1425, -73.6294)]

# %%
G = nx.complete_graph(len(ciudades))

# %%
for i in range(len(ciudades)):
      for j in range(i+1, len(ciudades)):
          ciudad1 = ciudades[i]
          ciudad2 = ciudades[j]
          dist = haversine.haversine((ciudad1[1], ciudad1[2]), (ciudad2[1], ciudad2[2]))
          G.add_weighted_edges_from([(i, j, dist)])

# %%
route = nx.algorithms.approximation.traveling_salesman_problem(G)
print("Rutas mas optimas")
print(route)
# Out:
# Rutas mas optimas
# [0, 6, 2, 1, 7, 8, 5, 3, 4, 9, 0]

# %%
ordered_ciudades = [ciudades[i] for i in route]
print("Ruta mas optima por nombres de las ciudades")
print(ordered_ciudades)
# Out:
# Ruta mas optima por nombres de las ciudades
# [('Bogota', 4.6126, -74.0705), ('Pereira', 4.8143, -75.6946), ('Cali', 3.44, -76.5197), ('Medellin', 6.2447, -75.5748), ('Bucaramanga', 7.1186, -73.1161), ('Valledupar', 10.4603, -73.2597), ('Soledad', 10.917119, -74.799151), ('Barranquilla', 10.9639, -74.7964), ('Cartagena', 10.4236, -75.5253), ('Villavicencio', 4.1425, -73.6294), ('Bogota', 4.6126, -74.0705)]

# %%
mapa = folium.Map(location=[ordered_ciudades[0][1], ordered_ciudades[0][2]], zoom_start=5)

# %%
for ciudad in ordered_ciudades:
    folium.Marker(location=[ciudad[1], ciudad[2]],popup=[ciudad[1], ciudad[2]]).add_to(mapa)

# %%
locations = [[ciudad[1], ciudad[2]] for ciudad in ordered_ciudades]
folium.PolyLine(locations=locations, weight=2.5, color='black').add_to(mapa)

# %%
# Mostrar el mapa en pantalla
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_70ae060e67d025736782ca8f451ca7ed {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_70ae060e67d025736782ca8f451ca7ed&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_70ae060e67d025736782ca8f451ca7ed = L.map(
#                 &quot;map_70ae060e67d025736782ca8f451ca7ed&quot;,
#                 {
#                     center: [4.6126, -74.0705],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_57d3c523c292e8e9895e1fb2e12ab602 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_70ae060e67d025736782ca8f451ca7ed);
#
#
#             var marker_99076c5cc75da09708ad716709bee638 = L.marker(
#                 [4.6126, -74.0705],
#                 {}
#             ).addTo(map_70ae060e67d025736782ca8f451ca7ed);
#
#
#         var popup_e16c66eb7377f29a0caee4d8fe9340fb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_aceb09b223078b08169620de72d12365 = $(`&lt;div id=&quot;html_aceb09b223078b08169620de72d12365&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;[4.6126, -74.0705]&lt;/div&gt;`)[0];
#                 popup_e16c66eb7377f29a0caee4d8fe9340fb.setContent(html_aceb09b223078b08169620de72d12365);
#
#
#
#         marker_99076c5cc75da09708ad716709bee638.bindPopup(popup_e16c66eb7377f29a0caee4d8fe9340fb)
#         ;
#
#
#
#
#             var marker_ece66a467e097ee15cdf159107b0abb5 = L.marker(
#                 [4.8143, -75.6946],
#                 {}
#             ).addTo(map_70ae060e67d025736782ca8f451ca7ed);
#
#
#         var popup_a724af8746353b44752e15fda5982ce6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_36d88ebabd5582d6c48b628b2391b62f = $(`&lt;div id=&quot;html_36d88ebabd5582d6c48b628b2391b62f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;[4.8143, -75.6946]&lt;/div&gt;`)[0];
#                 popup_a724af8746353b44752e15fda5982ce6.setContent(html_36d88ebabd5582d6c48b628b2391b62f);
#
#
#
#         marker_ece66a467e097ee15cdf159107b0abb5.bindPopup(popup_a724af8746353b44752e15fda5982ce6)
#         ;
#
#
#
#
#             var marker_783ed4811638fda5da476bec4593c391 = L.marker(
#                 [3.44, -76.5197],
#                 {}
#             ).addTo(map_70ae060e67d025736782ca8f451ca7ed);
#
#
#         var popup_69db22ec52b7928036325f77da72199e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2c073f5ded0e49d7255246b6b439d8ad = $(`&lt;div id=&quot;html_2c073f5ded0e49d7255246b6b439d8ad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;[3.44, -76.5197]&lt;/div&gt;`)[0];
#                 popup_69db22ec52b7928036325f77da72199e.setContent(html_2c073f5ded0e49d7255246b6b439d8ad);
#
#
#
#         marker_783ed4811638fda5da476bec4593c391.bindPopup(popup_69db22ec52b7928036325f77da72199e)
#         ;
#
#
#
#
#             var marker_be23fe7b8b1421be298e008a2821dae7 = L.marker(
#                 [6.2447, -75.5748],
#                 {}
#             ).addTo(map_70ae060e67d025736782ca8f451ca7ed);
#
#
#         var popup_38f49c494a7fc520ff144c44fdc0aa79 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_18b03dc1520982ad50163c0edc371408 = $(`&lt;div id=&quot;html_18b03dc1520982ad50163c0edc371408&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;[6.2447, -75.5748]&lt;/div&gt;`)[0];
#                 popup_38f49c494a7fc520ff144c44fdc0aa79.setContent(html_18b03dc1520982ad50163c0edc371408);
#
#
#
#         marker_be23fe7b8b1421be298e008a2821dae7.bindPopup(popup_38f49c494a7fc520ff144c44fdc0aa79)
#         ;
#
#
#
#
#             var marker_fd7f4858eebcfe275543bc9f7054c40f = L.marker(
#                 [7.1186, -73.1161],
#                 {}
#             ).addTo(map_70ae060e67d025736782ca8f451ca7ed);
#
#
#         var popup_4e7643d1d8d7eb9b365fb445b201f483 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_470377fe6b438327b52be2c87d379e86 = $(`&lt;div id=&quot;html_470377fe6b438327b52be2c87d379e86&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;[7.1186, -73.1161]&lt;/div&gt;`)[0];
#                 popup_4e7643d1d8d7eb9b365fb445b201f483.setContent(html_470377fe6b438327b52be2c87d379e86);
#
#
#
#         marker_fd7f4858eebcfe275543bc9f7054c40f.bindPopup(popup_4e7643d1d8d7eb9b365fb445b201f483)
#         ;
#
#
#
#
#             var marker_4d18bc946ef896cd09093669be2d5fb1 = L.marker(
#                 [10.4603, -73.2597],
#                 {}
